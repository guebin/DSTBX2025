# %% [raw]
# ---
# title: "Day3: vscode"
# author: "최규빈"
# date: "12/30/2024"
# draft: true
# ---

# %% [markdown]
# > 강의영상 요청하기
# >
# > - <https://drive.google.com/drive/folders/1NQGXdvjkBxTK5D9xleb_hDZzhUG_kPD2?usp=sharing>

# %% [markdown]
# 로그인: 깃헙

# %% [markdown]
# local

# %% [markdown]
# ![*제 local extension*](attachment:image.png)

# %% [markdown]
# remote

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# `-` 설정하기

# %% [markdown]
# ![](attachment:image.png)
