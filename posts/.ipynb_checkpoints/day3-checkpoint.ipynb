# %% [raw]
# ---
# title: "Day3: vscode 설치 -- 리소스관리"
# author: "최규빈"
# date: "12/30/2024"
# ---

# %% [markdown]
# > 강의영상 요청하기
# >
# > - <https://drive.google.com/drive/asdf>

# %% [markdown]
# ## vscode 설치

# %% [markdown]
# `-` vscode 다운로드 및 설치

# %% [markdown]
# ## ssh 설정

# %% [markdown]
# `-` EXTENSTIONS 에서 아래를 설치 (`Remote - SSH` 만 설치하면 나머지는 자동설치됨)
#
# - `Remote - SSH`
# - `Remote - SSH: Editing Configuration Files`
# - `Remote Explorer`

# %% [markdown]
# `-` REMOTE EXPLORER 열기

# %% [markdown]
# ![](attachment:73c655b9-9f1c-4a32-99fa-ecb149c5008a.png)

# %% [markdown]
# - `ssh` 접속시 사용하는 코드 작성

# %% [markdown]
# `-` 터미널이 아래와 같이 바뀌면 성공

# %% [markdown]
# ![](attachment:57faeb1e-f441-4bb6-b9cc-3e9ddc92aa22.png)

# %% [markdown]
# ## EXTENSIONS

# %% [markdown]
# `-` 저의 LOCAL EXTENSIONS

# %% [markdown]
# ![](attachment:7b213bc0-f87e-4473-8ba4-2cd98343b255.png)

# %% [markdown]
# `-` 저의 REMOTE EXTENSIONS

# %% [markdown]
# ![](attachment:59d18121-ba2b-43f9-a4ab-131d04741ac7.png)

# %% [markdown]
# ## `.ipynb`에서 커널선택

# %% [markdown]
# ### `python` 커널

# %% [markdown]
# `-` local(현재는 186는 컴퓨터를 지칭)의 python 커널을 선택하기 위해서 아래에서 `Python Environments...` 선택

# %% [markdown]
# ![](attachment:cd1ca0c9-3456-4a6a-82ca-c1941919f649.png)

# %% [markdown]
# `-` 설치된 모든 스펙을 표시해줌

# %% [markdown]
# ![](attachment:164ae741-5572-49b3-bcf6-bb9d38b4a626.png)

# %% [markdown]
# `-` 각 경로의 python 확인해보기
#
# ```bash
# ls py* # py로 시작하는 파일/폴더명을 출력
# ```

# %% [markdown]
# `-` 질문: 몇개의 컴퓨터가 있다고 보여지는가?
#
# > `/root`, `(base)`, `(first)`, `(renv)`, `(rpy2)` 가 있다고 생각됨
#
# `-` 질문: 각각의 python은 어떤 컴퓨터에 설치되어있는가? (그리고 이러한 python을 언제 설치했는가?)
#
# - `/bin/python3`은 어떤 컴퓨터에 설치되어있는가?
# - `usr/bin/python3`은 어떤 컴퓨터에 설치되어있는가?
# - `anaconda3/bin/python`은 어떤 컴퓨터에 설치되어있는가?
# - `anaconda3/envs/first/bin/python`은 어떤 컴퓨터에 설치되어있는가?
# - `anaconda3/envs/renv/bin/python`은 어떤 컴퓨터에 설치되어있는가?
# - `anaconda3/envs/rpy2/bin/python`은 어떤 컴퓨터에 설치되어있는가?

# %% [markdown]
# ### `R` 커널

# %% [markdown]
# `-` local(현재는 186는 컴퓨터를 지칭)의 R 커널을 선택하기 위해서 아래에서 `Jupyter Kernel...` 선택

# %% [markdown]
# ![](attachment:cd1ca0c9-3456-4a6a-82ca-c1941919f649.png)

# %% [markdown]
# `-` 아래를 선택 (선택의 여지가 없음)

# %% [markdown]
# ![](attachment:af121bf8-6251-455b-9d43-f8c15140025c.png)

# %% [markdown]
# `-` 질문: 왜 rpy2에 설치된 R은 등록되지 않는가?
#
# - 저기에는 Jupyter Kernel에 등록된 list만 보입니다.
# - 그런데 (rpy2)의 R은 Jupyter Kernel에 등록하지 않았어요.
# - (renv)의 R은 등록했습니다. 콘다에서 r-essentials 를 설치할때 자동등록..

# %% [markdown]
# ## 환경만드는 팁

# %% [markdown]
# `-` `(base)` 에 설치하는 방법은 피한다.
#
# `-` 가능하면 `/root` 자체에 뭘 설치하는 경우는 피한다.
#
# ```bash
# apt-get
# ```
#
# `-` 충돌관리가 어려워보이는 패키지는 `conda install` 을 사용한다. 별 충돌이 없을거라 생각하는 패키지는 `pip install` 을 사용한다.
#
# `-` 가상환경을 설계하는 것은 논리적으로 접근해서 해결 할 수 있는 문제가 아니다. 시행착오를 통해 답을 찾아야 한다. (구글도 실패한다니까요?)

# %% [markdown]
# ## 환경만들기: `torch`

# %% [markdown]
# `-` 아래가 동작하는 환경을 구성해 볼 것

# %% [markdown]
# ```Python
# Python 3.12.2 | packaged by conda-forge | (main, Feb 16 2024, 20:50:58) [GCC 12.3.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>> import torch
# >>> torch.cuda.is_available()
# True
# >>>
# ```

# %% [markdown]
# `-` 아래의 코드를 주피터노트북에서 실행해 볼 것.
#
# ```Python
# import torch
# torch.cuda.is_available()
# ```

# %% [markdown]
# ## 환경만들기: `scikit-learn`

# %% [markdown]
# > ref: <https://scikit-learn.org/stable/auto_examples/cluster/plot_ward_structured_vs_unstructured.html#sphx-glr-auto-examples-cluster-plot-ward-structured-vs-unstructured-py>

# %% [markdown]
# `-` [여기로](https://scikit-learn.org/stable/auto_examples/cluster/plot_ward_structured_vs_unstructured.html#sphx-glr-auto-examples-cluster-plot-ward-structured-vs-unstructured-py) 이동하여 노트북을 다운로드하고, 이것이 동작하는 환경을 설계하라.

# %% [markdown]
# ## 환경만들기: `HuggingFace`

# %% [markdown]
# > ref1: <https://guebin.github.io/MP2024/quiz/Quiz-7.html>

# %% [markdown]
# > ref2: <https://huggingface.co/docs/transformers/en/installation>

# %% [markdown]
# `-` 아래의 명령어를 이용하여 노트북을 다운로드하고, 이것이 동작하는 환경을 설계하라.
#
# ```bash
# !wget https://raw.githubusercontent.com/guebin/MP2024/refs/heads/main/quiz/Quiz-7.ipynb
# ```

# %% [markdown]
# ## 환경만들기: `AutoGluon`

# %% [markdown]
# > ref: <https://auto.gluon.ai/stable/tutorials/tabular/tabular-quick-start.html>

# %% [markdown]
# `-` [여기](https://auto.gluon.ai/stable/tutorials/tabular/tabular-quick-start.html)의 코드가 동작하는 환경을 설계하라.

# %% [markdown]
# ## `.py`를 이용한 코딩

# %% [markdown]
# `-` 아래를 설정

# %% [markdown]
# ![](attachment:bdd0a922-3f42-4b2a-b947-7edc3adeb859.png)

# %% [markdown]
# `-` test.py 파일 생성

# %% [markdown]
# ```Python
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# x=np.array([1,2,3,4])
# y=np.array([1,2,4,3])
# pd.DataFrame({'x':x, 'y':y})
# plt.plot(x,y)
# print(x+y)
# ```

# %% [markdown]
# `-` `shift + enter` 실행해보기

# %% [markdown]
# `-` `Interactive-1`을 저장해보기

# %% [markdown]
# `-` `Run Python File` 로 실행해보기

# %% [markdown]
# `-` 커널을 바꾸어서 실습해보기

# %% [markdown]
# :::{.callout-important}
# vscode 기본설정들
# :::

# %% [markdown]
# ## `bash` 커널

# %% [markdown]
# `# 예제1`
#
# ```bash
# echo hello
# ```
#
# `#`

# %% [markdown]
# `# 예제2`
#
# ```bash
# a=askdf
# a
# $a
# echo $a
# ```
#
# `#`

# %% [markdown]
# > `a = asdf` 라고 입력하면 오류가 발생한다.

# %% [markdown]
# `# 예제3`
#
# ```bash
# a=(상민 다빈)
# echo $a
# echo ${a}
# echo ${a[0]}
# echo ${a[1]}
# echo ${a[@]}
# ```
#
# `#`

# %% [markdown]
# `# 예제4`
#
# ```bash
# cmd_list=(ls "ls -a")
# ${cmd_list}
# ${cmd_list[0]}
# ${cmd_list[1]}
# ```
#
# `#`

# %% [markdown]
# :::{.callout-important}
# terminal도 커널이었음!!
# :::

# %% [markdown]
# ## `export`

# %% [markdown]
# `-` 걱정: 근데 그러면 내 리눅스에는 평생 `a`, `cmd_list` 라는 변수가 있는거야??
#
# - 아니요

# %% [markdown]
# `-` 평생존재하는 변수도 있다. (환경변수)

# %% [markdown]
# ```bash
# env
# ```

# %% [markdown]
# `-` `bash`커널에서 아래를 이용하여 `ipython`을 실행하자.

# %% [markdown]
# ```bash
# ipython
# ```

# %% [markdown]
# `-` 일반변수는 `ipython`이 상속받지 못하지만 환경변수는 `ipython`이 상속받는다.

# %% [markdown]
# ```bash
# a=asdf
# ipython
# ```

# %% [markdown]
# ```Python
# !echo $a
# !echo $PATH
# ```

# %% [markdown]
# > 모두 대문자로 선언된 변수는 subprocess를 뚫고 갈 수 있다. 기계학습코드들에서 보면 하이퍼파라메터를 설정할때 모두 대문자로 설정하는 경우가 종종 있는데, 리눅스의 환경변수에서 유래되지 않았을까?

# %% [markdown]
# `-` 그런데 `export` 를 하면 상속받을 수 있다.

# %% [markdown]
# ```bash
# a=asdf
# b=1234
# export a
# ipython
# ```

# %% [markdown]
# ```Python
# !echo $a
# !echo $b
# !echo $PATH
# ```

# %% [markdown]
# > `ipython`을 subprocess라고 한다.

# %% [markdown]
# :::{.callout-important}
# subprocess의 이해, 환경변수의 이해
# :::

# %% [markdown]
# ## `check_ports.sh`

# %% [markdown]
# `-` `/root` (=`~`) 에 아래와 같은 소스코드를 가진 `check_ports.sh`를 만들자.

# %% [markdown]
# ```{.bash filename=/root/check_ports.sh}
# #!/bin/bash
# # Bash 스크립트 시작을 알리는 선언문
#
# # 기준 학번 설정
# student_id="13052"
#
# # 숫자 목록을 저장할 배열 초기화
# modified_numbers=()
#
# # 만의 자리를 바꾼 숫자 생성
# for i in {1..4}; do
#     # 현재 반복 중인 숫자 `i`가 student_id의 만의 자리와 같지 않을 때 실행
#     if [[ "${student_id:0:1}" != "$i" ]]; then
#         # 만의 자리를 `i`로 대체하고 나머지 숫자는 그대로 둔 새로운 숫자를 배열에 추가
#         modified_numbers+=("${i}${student_id:1}")
#     fi
# done
#
# # 십의 자리를 바꾼 숫자 생성
# for i in {0..9}; do
#     if [[ "${student_id:3:1}" != "$i" ]]; then
#         modified_numbers+=("${student_id:0:3}${i}${student_id:4}")
#     fi
# done
#
#
# # 테이블 헤더 출력
# echo -e "Port\tPID\tCommand"
#
# # 배열의 각 포트 번호에 대해 처리
# for port in "${modified_numbers[@]}"; do
#     # lsof 명령을 사용하여 해당 포트 번호의 PID와 COMMAND를 추출
#     result=$(lsof -i:"$port" 2>/dev/null | awk 'NR==2 {print $2, $1}' | head -n 1)
#
#     # 결과가 비어 있으면 프로세스가 없음을 의미
#     if [[ -z "$result" ]]; then
#         pid="N/A"          # PID를 N/A로 설정
#         command="N/A"      # COMMAND를 N/A로 설정
#     else
#         # 결과에서 PID와 COMMAND를 각각 추출
#         pid=$(echo "$result" | awk '{print $1}')
#         command=$(echo "$result" | awk '{print $2}')
#     fi
#
#     # 포트 번호, PID, COMMAND를 테이블 형식으로 출력
#     echo -e "$port\t$pid\t$command"
# done
# ```

# %% [markdown]
# ## 주피터랩 편하게

# %% [markdown]
# `-` (아무 conda 환경에서나) 아래를 실행한다.
#
# ```bash
# jupyter notebook --generate-config
# ```

# %% [markdown]
# `-` 아래를 수정한다.

# %% [markdown]
# ```Python
# c.ServerApp.allow_root = True
# c.ServerApp.ip = '0.0.0.0'
# ```

# %% [markdown]
# :::{.callout-note}
#
# 이것을 하면
#
# ```bash
# jupyter lab --allow-root --ip="0.0.0.0"
# ```
#
# 대신
#
# ```bash
# jupyter lab
# ```
#
# 을 하여도 같은 효과이다.
# :::

# %% [markdown]
# `-` 이를 이용하여 비어있는 포트에 몇개의 Jupyter를 띄우자.

# %% [markdown]
# :::{.callout-important}
# 주피터랩을 좀 편하게 열자
# :::

# %% [markdown]
# ## 문자열 결합

# %% [markdown]
# `-` 아래를 실행하고 관찰하자.

# %% [markdown]
# ```bash
# a=123
# echo $a
# echo ${a}456
# ```

# %% [markdown]
# ## PATH의 비밀

# %% [markdown]
# `-` 의문1: 왜 `git`, `python` 은 아무데서나 실행되는데 `bash check_ports.sh`는 아무데서나 실행불가능한거지?

# %% [markdown]
# `-` 의문2: 왜 `(base)`에서 `python`을 실행하면 찰떡같이 `/root/anaconda3/bin/python` 이 실행되는거지?

# %% [markdown]
# `-` 아래를 관찰
#
# ```bash
# echo $PATH | tr ":" "\n"
# ```

# %% [markdown]
# `-` 도전!: 아무데서나 `bash check_ports.sh`를 실행되게 하려면?

# %% [markdown]
# ```bash
# PATH=$PATH:~
# export PATH
# ```

# %% [markdown]
# `-` 위의 코드를 다른 새로운 `bash` 에서도 자동적용되게 하려면? `.bashrc`파일을 열고 아래를 추가한다.
#
# ```bash
# PATH=$PATH:~
# export PATH
# ```

# %% [markdown]
# > 근데 저는 이걸 굳이 설정하진 않아요

# %% [markdown]
# :::{.callout-important}
# PATH의 이해
# :::

# %% [markdown]
# ## Rstudio처럼 쓰기

# %% [markdown]
# `-` `R`을 vscode에서 쓰고 싶다면? (굳이?..)

# %% [markdown]
# - ref: <https://code.visualstudio.com/docs/languages/r>

# %% [markdown]
# > 이거 제가 써보니까 진짜 좋긴하거든요.. 그런데 셋팅하는게 까다로워요, 그래서 굳이 셋팅해줄 필요가 있나 싶긴한데요, PATH 사용을 연습삼아 해봅시다

# %% [markdown]
# `-` 설치과정
#
# - step1. `R` 설치
# - step2. `languageserver` 설치
# - step3. `radian` 설치
# - step4. `httpgd` 설치
# - step5. `R extension for Visual Studio Code` 설치
# - step6. vscode 환경설정 -- (까다로움 $\star$)

# %% [markdown]
# `-` step1-step4의 과정

# %% [markdown]
# *bash* -- `R` 설치

# %% [markdown]
# ```bash
# conda create -n renv
# conda activate renv
# conda install r::r-essentials
# R
# ```

# %% [markdown]
# *R* -- languageserver 설치

# %% [markdown]
# ```R
# install.packages("languageserver")
# ```

# %% [markdown]
# *bash* -- radian 설치
#
# ```bash
# conda install -c conda-forge radian
# ```

# %% [markdown]
# *R* -- httpgd 설치

# %% [markdown]
# ```R
# install.packages("httpgd")
# ```

# %% [markdown]
# `-` step5의과정: Vscode의 R-extension 설치

# %% [markdown]
# `-` step6을 잘 해결하는게 중요합니다.
#
# *아래를 진행해보기 -- local 이 아니라 remote 의 설정에서 진행해야함!!!*
#
# 1. *"R › Rpath: Linux"* 에서 `/root/anaconda3/envs/renv/bin/R`
# 2. *"R > Rterm: Linux"* 에서 `/root/anaconda3/envs/renv/bin/R`
# 3. test
# 4. *"R > Plot: Use Httpgd:* 체크
# 5. test
# 6. *"R > Rterm: Linux"* 에서 `/root/anaconda3/envs/renv/bin/radian` 으로 변경
# 7. test
# 8. 에러 관찰하기: `(base)` 에서 `/root/anaconda3/envs/renv/bin/radian` 실행해보기
# 9. 해결해보기: `R_HOME` 에 "/root/anaconda3/envs/renv/lib/R" 를 설정하고 다시 5를 해보기

# %% [markdown]
# *"Terminal > Integrated > Env: Linux"* 을 통하여 5의 오류 수정하기

# %% [markdown]
# ```{json}
#     "terminal.integrated.env.linux": {
#         "R_HOME": "/root/anaconda3/envs/renv/lib/R"
#     }
# ```

# %% [markdown]
# *최종적인 환경*
#
# -- 최종환경그림
# ![](attachment:fb3fd667-a4c2-4f7e-a886-3a94ce0c7f5f.png)
#
# -- 최종환경 `json`
#
# ```{json}
# {
#     "jupyter.interactiveWindow.textEditor.executeSelection": true,
#     "r.rpath.linux": "/root/anaconda3/envs/renv/bin/R",
#     "r.rterm.linux": "/root/anaconda3/envs/renv/bin/radian",
#     "r.plot.useHttpgd": true,
#     "terminal.integrated.env.linux": {
#         "R_HOME": "/root/anaconda3/envs/renv/lib/R"
#     },
# }
# ```

# %% [markdown]
# :::{.callout-important}
# vscode에서 R 개발환경을 셋팅하는것 보다 환경변수 R_HOME을 조작해보는것이 더 중요함. 셋팅과정에서 문제가 발생하는 이유는 기본적으로 아나콘다를 사용한다는 전제 없이 base에서 억지로 R을 연결하기 때문에 일어나는 문제임 (즉 R을 아나콘다 없이 사용할 경우 발생하지 않는 문제임)
# :::

# %% [markdown]
# ## `jupyter`와 `vscode`의 차이

# %% [markdown]
# `-` jupyter는 프로그램을 꺼도 커널이 죽지 않지만 vscode는 프로그램을 끄는 순간 커널이 죽음
#
# - 연속작업에 치명적인 차이가 남

# %% [markdown]
# `-` 극복하는 방법?
#
# - 살짝트릭: vscode에서 주피터 커널을 물리면 된다.

# %% [markdown]
# `-` 이 원리를 이용하면 local의 `.ipynb`에 원격 vscode 를 물릴 수 있다.
#
# - 그런데 주의해서 사용해야함.
# - 저는 안써요

# %% [markdown]
# :::{.callout-important}
# 주피터랩과 vscode 각각 편한점이 있음. 잘 쓰는 사람들은 vscode를 더 편하게 생각함. (저는 주피터가 더 편함)
# :::

# %% [markdown]
# ## 리소스관리

# %% [markdown]
# `-` 메모리, CPU 사용량 체크

# %% [markdown]
# ```bash
# top
# ```

# %% [markdown]
# *테스트코드*

# %% [markdown]
# ```Python
# ## 1. Imports
# import numpy as np
# import time
#
# ## 2. 개념설명
# n = 5
# x = np.array(range(n))
# dist1 = np.zeros([n,n])
# for i in range(n):
#     for j in range(n):
#         dist1[i,j]=(x[i]-x[j])**2
# print(dist1)
# x1=x.reshape(n,1).astype(dtype=np.float64)
# x2=x.reshape(1,n).astype(dtype=np.float64)
# dist2=(x1-x2)**2
# print(dist2)
#
# ## 3. CPU vs MEM
# n = 10000
# x = np.array(range(n))
# t1 = time.time()
# dist1 = np.zeros([n,n])
# for i in range(n):
#     for j in range(n):
#         dist1[i,j]=(x[i]-x[j])**2
# t2 = time.time()
# print(t2-t1)
# t1 = time.time()
# x1=x.reshape(n,1).astype(dtype=np.float64)
# x2=x.reshape(1,n).astype(dtype=np.float64)
# dist2=(x1-x2)**2
# t2 = time.time()
# print(t2-t1)
#
# ## 4. MEM 사용량증가
# n = 100000
# x = np.array(range(n))
# # t1 = time.time()
# # dist1 = np.zeros([n,n])
# # for i in range(n):
# #     for j in range(n):
# #         dist1[i,j]=(x[i]-x[j])**2
# # t2 = time.time()
# # print(t2-t1)
# t1 = time.time()
# x1=x.reshape(n,1).astype(dtype=np.float64)
# x2=x.reshape(1,n).astype(dtype=np.float64)
# dist2=(x1-x2)**2
# t2 = time.time()
# print(t2-t1)
# ```

# %% [markdown]
# `-` GPU 사용량 체크

# %% [markdown]
# ```bash
# nvidia-smi
# watch -n 1 nvidia-smi
# ```

# %% [markdown]
# *test code*

# %% [markdown]
# ```Python
# import torch
# x = torch.randn([50000,10000])
# x.to("cuda:0")
# ```

# %% [markdown]
# `-` 하드디스크 용량체크: 아래를 반복적으로 치면서 찾아보자.
#
# ```bash
# du -sh *
# ```

# %% [markdown]
# `-` 휴지통비우기
